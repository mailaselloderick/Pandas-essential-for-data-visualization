# %%
import pandas as pd

# %% [markdown]
# 1.Read the data from the CSV file into a DataFrame and display the first five rows.

# %%
df_ramen=pd.read_csv('ramen-ratings.csv')
df_ramen.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %% [markdown]
# 2.Create a histogram for the Stars column using the number of bins necessary to display the ratings for each quarter of a star

# %%
df_ramen.plot.hist(y='Stars',bins=2)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 3.Create a KDE plot for the Stars column

# %%
df_ramen.plot.density(y='Stars')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# 4.Create a bar plot that shows the average number of stars by ramen style. Hint: You’ll need to group the data before you plot it.

# %%
df_ramen.groupby('Style').Stars.mean().plot.bar(title='The average number of stars by ramen style')
# Out:
# <Axes: title={'center': 'The average number of stars by ramen style'}, xlabel='Style'>

# %% [markdown]
# 5.Create a bar plot that shows the total number of reviews for each ramen type

# %%
df_ramen.groupby('Style').Stars.sum().plot.bar(title='The total number of reviews for each ramen type',ylabel='Total Reviews',xlabel='Ramen Type')
# Out:
# <Axes: title={'center': 'The total number of reviews for each ramen type'}, xlabel='Ramen Type', ylabel='Total Reviews'>

# %% [markdown]
# 6.Create a bar plot that shows the highest score given to each ramen type.

# %%
df_ramen.groupby('Style').Stars.max().plot.bar(title='The highest Score Of Ramen Type',ylabel='Total Score',xlabel='Ramen Type')
# Out:
# <Axes: title={'center': 'The highest Score Of  Ramen Type'}, xlabel='Ramen Type', ylabel='Total Score'>

# %% [markdown]
# 1.What is the most common style of ramen?

# %%
df_ramen.Style.value_counts()
# Out:
# Style
# Pack    1528
# Bowl     481
# Cup      450
# Tray     108
# Box        6
# Can        1
# Bar        1
# Name: count, dtype: int64

# %%
most_common_style=df_ramen['Style'].value_counts().idxmax()
most_count_style=df_ramen['Style'].value_counts().max()

print(f"{most_common_style} with {most_count_style} entries")
# Out:
# Pack with 1528 entries
