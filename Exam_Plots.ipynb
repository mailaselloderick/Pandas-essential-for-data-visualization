# %%
import pandas as pd

# %% [markdown]
# 1.Read the data from the CSV file into a DataFrame and display the first five rows

# %%
df_exam=pd.read_csv('exams.csv')
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# 2.Use the pandas plot() method to create a box plot.

# %%
df_exam.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# Use the pandas plot() method to create a plot like the one displayed in Figure 1.

# %%
df_exam.plot.scatter(y='reading score',x='math score')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %% [markdown]
# 4.Group the data by the gender column and calculate the average scores. Then create a bar plot.

# %%
Average_scores= df_exam.groupby('gender')[['math score','reading score','writing score']].mean().plot.bar()

# %% [markdown]
# Questions: (Answer questions by writing the code to back up your answer)

# %% [markdown]
# 1.What is the relationship between the reading score and the writing score?

# %%
correlation = df_exam["reading score"].corr(df_exam["writing score"])
correlation
# Out:
# np.float64(0.9545980771462478)

# %%
df_exam[['reading score','writing score']].value_counts()
# Out:
# reading score  writing score
# 100            100              11
# 72             70                7
# 64             66                7
# 73             68                6
# 74             72                6
#                                 ..
# 91             87                1
#                81                1
# 90             94                1
#                93                1
#                89                1
# Name: count, Length: 617, dtype: int64

# %% [markdown]
# 2.Does the type of lunch appear to have an effect on the average test scores?

# %%
df_exam.groupby('lunch')[['math score','reading score','writing score']].mean().plot.bar()
# Out:
# <Axes: xlabel='lunch'>
